# %% [markdown]
# ** Use Case-1: Learn about Variables **

# %%
student_name = 'Arun'
course_name = 'Python Fundamentals'
training_institue = 'Inceptez Technologies'
print (student_name,"is learning the course",course_name, "at the institue of",training_institue)
# Out:
# Arun is learning the course Python Fundamentals at the institue of Inceptez Technologies

# %% [markdown]
# ** Use Case 2: Learn about Variables **

# %%
fee=45000
gst=0.18
tot = fee * gst
print (fee); print (gst); print (tot);
#print ('Fee with 18% of GST'+tot);  # Strongly Type: can only concatenate str (not "float") to str
# Out:
# 45000
# 0.18
# 8100.0

# %% [markdown]
# ** Use Case -1: Variables Naming Conversions **

# %%
# 2stundent = 'Ravi'  Variable name should not start with number (Invalid decimal literal)
_student_id = 1001 # Variable name can start with underscore (_)
studentName = 'Kumaran'
#class name = 'Python'  Variable name should not contain any spaces.(Invalid Syntax)
inceptz_batch = 'Daily Morning Batch'
print (_student_id); print (studentName); print (inceptz_batch);
# Out:
# 1001
# Kumaran
# Daily Morning Batch

# %% [markdown]
# ** Use Case -2 Variables Naming Conversions **

# %%
StudentName = 'Kumaran M' # Pascal Case Variable Style
studentName = 'Kumaran M' # Camel Case Variable Style
student_name = 'Kumaran M' # Snake Case Variable Style

# %% [markdown]
# ** Use Case -1: Type Identification & Casting **

# %%
age = input("Enter an Employee Age")
print (type(age))
age = int(age)
print (type(age))
remaining_age = 60 - age
print (remaining_age)
# Out:
# <class 'str'>
# <class 'int'>
# 10

# %% [markdown]
# ** Use Case-2: Type Identification & Casting **

# %%
salary = '50000'
bonus = 10000
#print ("Total Salary in Inceptez", salary + bonus) #can only concatenate str (not "int") to str
salary = 50000
print ("Total Salary in Inceptez", salary + bonus)
# Out:
# Total Salary in Inceptez 60000

# %% [markdown]
# ** Use Case-1: Data Types and Casting **

# %%
employee_name = input("Enter an Employee Name")
base_salary = input("Enter Basic Salary")
hra_percent = input("Enter HRA Percentage")
bonus_amount = input ("Enter Bonus Amount")
print (type(employee_name)); print (type(base_salary)); print (type(hra_percent)); print (type(bonus_amount));
hra = float(base_salary) * (int(hra_percent)/100)
total_salary = float(base_salary) + hra + float(bonus_amount)
print (float(base_salary)); print(hra); print (float(bonus_amount)); print (total_salary);
# Out:
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# 75000.0
# 30000.0
# 50000.0
# 155000.0

# %% [markdown]
# ** Use Case-2: Data Types and Casting: Student Result Classification **

# %%
marks = input("Enter the Marks")
print (type(marks))
'''if isinstance(marks, str):
    print ('Enter a valid number')'''
try:
    marks = float(marks)
    if float(marks) >= 90:
        print("Outstanding")
    elif float(marks) >= 75:
        print("Excellent")
    elif float(marks) >= 50:
        print("Pass")
    elif float(marks) < 50:
        print ("Fail")
except ValueError:
    print ('Enter a valid number')
# Out:
# <class 'str'>
# Outstanding

# %%
item_name =input("Enter price per item: ")
price = float(input("Enter price per item: "))
quantity = int(input("Enter quantity: "))
total_cost = price * quantity
print("You purchased ", quantity, " units of ", item_name)
print("Total payable: " , total_cost)
# Out:
# You purchased  100  units of  Note Book
# Total payable:  9999.0
